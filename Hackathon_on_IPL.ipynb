# %%
# Importing Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the deliveries csv file
PATH = 'deliveries.csv'
deli_df = pd.read_csv(PATH)
deli_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Loading matches csv file
path = 'matches.csv'
match_df = pd.read_csv(path)
match_df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# Finding missing values 
deli_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
# Finding missing values
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
# Treating missing values
deli_df['player_dismissed'] = df['player_dismissed'].fillna('NO')
deli_df['dismissal_kind'] = df['dismissal_kind'].fillna('NO')
deli_df['fielder'] = df['fielder'].fillna('NO')

match_df['winner'] = match_df['winner'].fillna('no result')
match_df['player_of_match'] = match_df['player_of_match'].fillna('no result')
match_df['umpire1'] = match_df['umpire1'].fillna('NO')
match_df['umpire2'] = match_df['umpire2'].fillna('NO')
match_df['umpire3'] = match_df['umpire3'].fillna('NO')
match_df['city'] = match_df['city'].fillna('not specified')

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             756 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           756 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  756 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          756 non-null    object
#  16  umpire2          756 non-null    object
# ...

# %%
deli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # Data Analysis

# %%
# Teams with Most Wins
plt.figure(figsize=(10, 6))
match_df['winner'].value_counts().plot(kind='bar')
plt.title('Teams with Most Wins')
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation:** Mumbai indians won most of the times.

# %%
# percentage of getting bat and field in feature 'toss_descision' 
toss_decisions = match_df['toss_decision'].value_counts()

# Plotting pie chart for toss decisions
plt.figure(figsize=(6, 6))
plt.pie(toss_decisions, labels=toss_decisions.index, autopct='%1.1f%%', startangle=140)
plt.title('Toss Decisions Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Observation:** Teams winning tosses and electing field first have won more number of matches.

# %%
# wicket-based wins
wicket_wins = match_df[match_df['win_by_wickets'] > 0]['win_by_wickets'].value_counts().sort_index()

# Plotting bar plot for wins by wickets
plt.figure(figsize=(10, 6))
wicket_wins.plot(kind='bar', color='skyblue')
plt.title('Wins by Wickets')
plt.xlabel('Wickets')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** mostly won by 6 wickets

# %%
# Teams win by wickets
wicket_wins_by_team = match_df[match_df['win_by_wickets'] > 0]['winner'].value_counts()

plt.figure(figsize=(10, 6))
wicket_wins_by_team.plot(kind='bar', color='skyblue')
plt.title('Team-wise Wins by Wickets')
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** Kolkata knight Riders won highest times compared to others.

# %%
# Batsman Runs Distribution
batsman_runs = deli_df.groupby('batsman')['batsman_runs'].sum()

# Plotting histogram for batsman runs distribution
plt.figure(figsize=(8, 6))
plt.hist(batsman_runs, bins=30, color='skyblue', edgecolor='black')
plt.title('Batsman Runs Distribution')
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Extra Runs by Type
extra_runs = deli_df[['wide_runs', 'noball_runs', 'bye_runs', 'legbye_runs']].sum()

# Plotting bar plot for extra runs by type
plt.figure(figsize=(8, 6))
extra_runs.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen', 'gold'])
plt.title('Extra Runs by Type')
plt.xlabel('Extra Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** Wide runs are more compared to others.

# %%
# Counting dismissals by type
dismissals_by_type = deli_df['dismissal_kind'].value_counts()

# Plotting bar plot for dismissals by type
plt.figure(figsize=(8, 6))
dismissals_by_type.plot(kind='bar', color='lightblue')
plt.title('Dismissals by Type')
plt.xlabel('Dismissal Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Over-wise Runs
runs_by_over = deli_df.groupby('over')['total_runs'].sum()

# Plotting line plot for over-wise runs
plt.figure(figsize=(8, 6))
runs_by_over.plot(kind='line', marker='o', color='green')
plt.title('Over-wise Runs')
plt.xlabel('Over')
plt.ylabel('Total Runs')
plt.xticks(runs_by_over.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 'field_first_wins' and 'bat_first_wins' contain the respective counts
decisions = ['Field First', 'Bat First']
wins = [field_first_wins, bat_first_wins]

# Plotting the bar plot
plt.figure(figsize=(8, 6))
plt.bar(decisions, wins, color=['skyblue', 'lightgreen'])
plt.title('Matches Won based on Toss Decision')
plt.xlabel('Toss Decision')
plt.ylabel('Number of Matches Won')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** Teams winning tosses and electing field first have won more number of matches.

# %%
#  Number of matches hosted at each venue
venue_matches_count = match_df['venue'].value_counts()

# Selecting the venue with the most matches
most_matches_venue = venue_matches_count.idxmax()
most_matches_count = venue_matches_count.max()

# Plotting the number of matches hosted at each venue
plt.figure(figsize=(12, 6))
venue_matches_count.plot(kind='bar', color='skyblue')
plt.title('Number of IPL Matches Hosted per Venue')
plt.xlabel('Venues')
plt.ylabel('Number of Matches')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

print(f"The venue that has hosted the most number of IPL matches is '{most_matches_venue}' with {most_matches_count} matches.")
# Out:
# The venue that has hosted the most number of IPL matches is 'Eden Gardens' with 77 matches.

# %%
# Number of matches played in each year
matches_per_year = match_df['season'].value_counts().sort_index()

# Plotting the number of matches per year
plt.figure(figsize=(10, 6))
matches_per_year.plot(kind='bar', color='skyblue')
plt.title('Number of Matches Played Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** In 2013 >70 Matches were held

# %%
# Filtering rows where dismissal type is 'run out'
run_outs = deli_df[deli_df['dismissal_kind'] == 'run out']

# Counting run outs for each batsman
batsman_run_out_counts = run_outs['batsman'].value_counts().head(10)  # Change 'head(10)' to your desired number

# Plotting the batsmen with the most run-outs
plt.figure(figsize=(10, 6))
batsman_run_out_counts.plot(kind='bar', color='skyblue')
plt.title('Batsmen with Most Number of Run Outs')
plt.xlabel('Batsmen')
plt.ylabel('Number of Run Outs')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** M.S Dhoni has most No of run outs

# %%
boundary_counts = deli_df[deli_df['batsman_runs'].isin([4, 6])]['batsman'].value_counts()

# Selecting the top 10 players with the highest boundary count
top_boundary_players = boundary_counts.head(10)

# Plotting the players with the highest hard-hitting ability
plt.figure(figsize=(10, 6))
top_boundary_players.plot(kind='bar', color='skyblue')
plt.title('Players with Highest Boundary Hitting Ability')
plt.xlabel('Players')
plt.ylabel('Number of Boundaries')
# Out:
# Text(0, 0.5, 'Number of Boundaries')

# %% [markdown]
# **Observation:** CH Gayle with Highest Boundary Hitting Ability is nearly 700

# %%
# Across all seasons players dismissed the maximum number of times via caught and bowled
caught_and_bowled_dismissals = deli_df[deli_df['dismissal_kind'] == 'caught and bowled']

# Counting occurrences of 'caught and bowled' dismissals for each player
player_caught_and_bowled_count = caught_and_bowled_dismissals['batsman'].value_counts().head(10)  # Adjust number of players

# Plotting the players dismissed the most via 'caught and bowled'
plt.figure(figsize=(10, 6))
player_caught_and_bowled_count.plot(kind='bar', color='skyblue')
plt.title('Players Dismissed Most via Caught and Bowled')
plt.xlabel('Players')
plt.ylabel('Number of Dismissals')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** SK Raina Dismissed Most via Caught and Bowled

# %%
merged_df = pd.merge(deli_df, match_df, left_on='match_id', right_on='id')
merged_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# **Q) City which hosted most number of seasons according to the data?**

# %%
city_seasons = match_df.groupby('city')['season'].nunique().sort_values(ascending=False)

print("City hosting no of seasons:", city_seasons)
# Out:
# City hosting no of seasons: city
# Delhi             11
# Mumbai            11
# Kolkata           11
# Hyderabad         10
# Bangalore          9
# Chandigarh         9
# Chennai            8
# Jaipur             7
# Pune               6
# Dharamsala         4
# Visakhapatnam      4
# Cuttack            3
# Ranchi             3
# Indore             3
# Ahmedabad          3
# Raipur             3
# Rajkot             2
# Kanpur             2
# Bengaluru          2
# Mohali             2
# Nagpur             1
# Sharjah            1
# Port Elizabeth     1
# Cape Town          1
# Bloemfontein       1
# Durban             1
# Kochi              1
# Kimberley          1
# Johannesburg       1
# Centurion          1
# East London        1
# Abu Dhabi          1
# Name: season, dtype: int64

# %% [markdown]
# **Q) Which year has the most number of matches played?**

# %%
# Counting the number of matches for each year
matches_per_year= pd.to_datetime(match_df['date']).dt.year.value_counts()

print('matches_per_year: \n',matches_per_year)
# Out:
# matches_per_year:
#  2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: date, dtype: int64

# %% [markdown]
# **Q)  Maximum wins by Mumbai Indians in 2011?**

# %%
mi_2011 = match_df[(match_df['winner'] == 'Mumbai Indians') & (match_df['season'] == 2011)]

max_wins_mi_2011 = mi_2011['winner'].count()
print("Maximum wins by Mumbai Indians in 2011:", max_wins_mi_2011)
# Out:
# Maximum wins by Mumbai Indians in 2011: 10

# %% [markdown]
# **Q)  What is the percentage of getting bat and field in feature 'toss_descision'?**

# %%
toss_decision_percentage = match_df['toss_decision'].value_counts(normalize=True) * 100

print("Percentage of teams choosing to bat and field:\n", toss_decision_percentage)
# Out:
# Percentage of teams choosing to bat and field:
#  field    61.243386
# bat      38.756614
# Name: toss_decision, dtype: float64

# %% [markdown]
# **Q)   Which statement holds true?**

# %%
toss_winner_and_match_winner = match_df[match_df['toss_winner'] == match_df['winner']]

#  matches won by teams choosing to field first
field_first_wins = toss_winner_and_match_winner[toss_winner_and_match_winner['toss_decision'] == 'field']['winner'].count()
print('field_first_wins:',field_first_wins)

# matches won by teams choosing to bat first
bat_first_wins = toss_winner_and_match_winner[toss_winner_and_match_winner['toss_decision'] == 'bat']['winner'].count()
print('bat_first_wins:',bat_first_wins)
# Out:
# field_first_wins: 259
# bat_first_wins: 134

# %% [markdown]
# **Observation:** Teams winning tosses and electing field first have won more number of matches.

# %% [markdown]
# **Q) In which years where taking batting second have won more number of matches?**

# %%
batting_second_wins = match_df[match_df['team2'] == match_df['winner']]['season'].value_counts()

# Display years where teams batting second won more matches
print("Years where teams batting second won more matches:")
print(batting_second_wins)
# Out:
# Years where teams batting second won more matches:
# 2016    41
# 2011    40
# 2012    40
# 2013    39
# 2014    37
# 2008    36
# 2019    36
# 2017    33
# 2018    32
# 2009    30
# 2010    28
# 2015    25
# Name: season, dtype: int64

# %%
field_and_won = match_df[(match_df['toss_decision'] == 'field') & (match_df['winner'] == match_df['team2'])]

# Count the matches won by teams batting second due to fielding decision
field_batting_second_wins = field_and_won['season'].value_counts()

print("Years where teams batting second (due to fielding decision) have won more number of matches:", field_batting_second_wins)
# Out:
# Years where teams batting second (due to fielding decision) have won more number of matches: 2016    32
# 2019    31
# 2017    28
# 2011    27
# 2018    27
# 2014    24
# 2008    19
# 2012    18
# 2013    15
# 2009    14
# 2015    14
# 2010    10
# Name: season, dtype: int64

# %% [markdown]
# **Q)  To plot the most consistent batsmen among top 10 run getters, what plotting technique we use?**

# %%
top_10_batsmen = merged_df.groupby('batsman')['total_runs'].sum().nlargest(10).reset_index()

# Plotting the consistency of top 10 run-getters using a line plot
plt.figure(figsize=(10, 6))
for index, row in top_10_batsmen.iterrows():
    batsman_data = merged_df[merged_df['batsman'] == row['batsman']]
    runs_per_match = batsman_data.groupby('match_id')['batsman_runs'].sum().cumsum()
    matches_played = runs_per_match.index
    plt.plot(matches_played, runs_per_match, marker='o', label=row['batsman'])

plt.xlabel('Matches Played')
plt.ylabel('Total Runs')
plt.title('Consistency of Top 10 Run-Getters')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Q)  In 2019 which batsman scored highest number of runs by hitting 6's and 4's?**

# %%
boundary_runs_2019 = merged_df[(merged_df['season'] == 2019) & (merged_df['batsman_runs'].isin([4, 6]))]

# Batsman and sum the boundary runs
boundary_runs_by_batsman = boundary_runs_2019.groupby('batsman')['batsman_runs'].sum().reset_index()

sorted_boundary_runs = boundary_runs_by_batsman.sort_values(by='batsman_runs', ascending=False)

# Batsmen and their boundary runs in 2019
print("Batsmen and their runs scored via boundaries in 2019:")
print(sorted_boundary_runs)
# Out:
# Batsmen and their runs scored via boundaries in 2019:
#           batsman  batsman_runs
# 4      AD Russell           438
# 18       CH Gayle           392
# 22      DA Warner           358
# 44       KL Rahul           350
# 70      Q de Kock           334
# ..            ...           ...
# 20  CR Brathwaite             4
# 10     Avesh Khan             4
# 65         P Negi             4
# 25      DL Chahar             4
# 26    DS Kulkarni             4
#
# [108 rows x 2 columns]

# %% [markdown]
# **Q) Most number of wickets taken by a bowler?**

# %%
wickets_by_bowler = merged_df.groupby('bowler')['player_dismissed'].count().reset_index()

# Bowler with the most number of wickets
sorted_wickets = wickets_by_bowler.sort_values(by='player_dismissed', ascending=False)

# Bowlers and their respective number of wickets taken
print("Bowler and the number of wickets taken:")
print(sorted_wickets)
# Out:
# Bowler and the number of wickets taken:
#               bowler  player_dismissed
# 340       SL Malinga               188
# 93          DJ Bravo               168
# 7           A Mishra               165
# 126  Harbhajan Singh               161
# 264        PP Chawla               156
# ..               ...               ...
# 64         BJ Rohrer                 0
# 284      RA Tripathi                 0
# 283        RA Shaikh                 0
# 139           J Dala                 0
# 254       P Prasanth                 0
#
# [405 rows x 2 columns]

# %% [markdown]
# **Q) What is the strike rate of Kohli in 2016 ?**

# %%
kohli_2016 = merged_df[(merged_df['batsman'] == 'Virat Kohli') & (merged_df['season'] == 2016)]

# Total runs and total balls faced by Kohli in 2016
total_runs_kohli = kohli_2016['batsman_runs'].sum()
total_balls_faced_kohli = len(kohli_2016)

# Calculating the strike rate
if total_balls_faced_kohli > 0:
    strike_rate_kohli = (total_runs_kohli / total_balls_faced_kohli) * 100
    print("Virat Kohli's strike rate in 2016:", round(strike_rate_kohli, 2))
else:
    print("Virat Kohli did not face any balls in 2016.")
# Out:
# Virat Kohli did not face any balls in 2016.

# %% [markdown]
# **Q)  Bowlers with maximum number of extras?**

# %%
extras_by_bowler = merged_df.groupby('bowler')['extra_runs'].sum().reset_index()

sorted_extras = extras_by_bowler.sort_values(by='extra_runs', ascending=False)

print("Bowlers with the maximum number of extras:")
print(sorted_extras)
# Out:
# Bowler(s) with the maximum number of extras:
#            bowler  extra_runs
# 340    SL Malinga         293
# 251       P Kumar         236
# 381      UT Yadav         219
# 93       DJ Bravo         201
# 53        B Kumar         197
# ..            ...         ...
# 23   AC Gilchrist           0
# 254    P Prasanth           0
# 77       CJ McKay           0
# 327      SA Yadav           0
# 255    P R Barman           0
#
# [405 rows x 2 columns]

# %% [markdown]
# **Q)  Which venue has hosted most number of IPL matches?**

# %%
venue_matches_count = match_df['venue'].value_counts().reset_index()
venue_matches_count.columns = ['Venue', 'Matches Hosted']

# Sort venues based on the number of matches hosted in descending order
sorted_venues = venue_matches_count.sort_values(by='Matches Hosted', ascending=False)

print("Venues and the number of IPL matches hosted:")
print(sorted_venues)
# Out:
# Venues and the number of IPL matches hosted:
#                                                 Venue  Matches Hosted
# 0                                        Eden Gardens              77
# 2                                    Wankhede Stadium              73
# 1                               M Chinnaswamy Stadium              73
# 3                                    Feroz Shah Kotla              67
# 4           Rajiv Gandhi International Stadium, Uppal              56
# 5                     MA Chidambaram Stadium, Chepauk              49
# 6                              Sawai Mansingh Stadium              47
# 7          Punjab Cricket Association Stadium, Mohali              35
# 8             Maharashtra Cricket Association Stadium              21
# 10                         Dr DY Patil Sports Academy              17
# 9                          Subrata Roy Sahara Stadium              17
# 11                                          Kingsmead              15
# ...

# %% [markdown]
# **Q)  In 2017 when sunrisers hyderabad clashed against Royal Challengers Bangalore which team player won player of the match?**

# %%
# Filter records of SRH and RCB match in 2017
match_2017 = match_df[(match_df['team1'] == 'Sunrisers Hyderabad') &
                        (match_df['team2'] == 'Royal Challengers Bangalore') &
                        (match_df['season'] == 2017)]

# 'Player of the Match' for that match
player_of_match = match_2017['player_of_match'].iloc[0]

print("Player of the Match: ", player_of_match)
# Out:
# Player of the Match:  Yuvraj Singh

# %% [markdown]
# **Q) Across seasons who are the top three batsman's with most number of run out?**

# %%
run_out_dismissals = merged_df[merged_df['dismissal_kind'] == 'run out']

# Group by batsman and count the number of run-outs
run_out_counts = run_out_dismissals['batsman'].value_counts().reset_index()
run_out_counts.columns = ['Batsman', 'Run Outs']

print(run_out_counts)
# Out:
#          Batsman  Run Outs
# 0       MS Dhoni        21
# 1      RG Sharma        17
# 2     KD Karthik        16
# 3      G Gambhir        15
# 4        V Kohli        15
# ..           ...       ...
# 272   RR Bhatkal         1
# 273      T Kohli         1
# 274  PC Valthaty         1
# 275   SP Fleming         1
# 276    J Suchith         1
#
# [277 rows x 2 columns]

# %% [markdown]
# **Q) What are the total runs scored by V Kohli when the bowler was JJ Burmah?**

# %%
# Filter data for V Kohli facing JJ Bumrah
kohli_vs_bumrah = deli_df[(deli_df['batsman'] == 'V Kohli') & (deli_df['bowler'] == 'JJ Bumrah')]

# Total runs scored by Kohli against Bumrah
total_runs_kohli_vs_bumrah = kohli_vs_bumrah['total_runs'].sum()

print("Total runs scored by V Kohli against JJ Bumrah:", total_runs_kohli_vs_bumrah)
# Out:
# Total runs scored by V Kohli against JJ Bumrah: 114

# %% [markdown]
# **Q) cross all seasons which player was dismissed the maximum number of times via caught and bowled?**

# %%
# Filter data for 'caught and bowled'
caught_and_bowled = deli_df[deli_df['dismissal_kind'] == 'caught and bowled']

# Find the player dismissed the most via 'caught and bowled'
most_caught_and_bowled = caught_and_bowled['player_dismissed'].value_counts()

print("Player dismissed the maximum number of times via 'caught and bowled':", most_caught_and_bowled)
# Out:
# Player dismissed the maximum number of times via 'caught and bowled': SK Raina      7
# RG Sharma     6
# AT Rayudu     5
# RA Jadeja     5
# R Dravid      5
#              ..
# AB Agarkar    1
# ML Hayden     1
# IK Pathan     1
# MK Tiwary     1
# JC Buttler    1
# Name: player_dismissed, Length: 120, dtype: int64

# %% [markdown]
# **Q) which player has the highest hard-hitting ability?**

# %%
sixes_by_player = deli_df[deli_df['batsman_runs'] == 6]

# Count the number of sixes hit by each batsman
sixes_count = sixes_by_player['batsman'].value_counts().reset_index()
sixes_count.columns = ['Player', 'Sixes']

# Display the players and their respective number of sixes hit
print(sixes_count)
# Out:
#              Player  Sixes
# 0          CH Gayle    327
# 1    AB de Villiers    214
# 2          MS Dhoni    207
# 3          SK Raina    195
# 4         RG Sharma    194
# ..              ...    ...
# 331     Sunny Singh      1
# 332       R McLaren      1
# 333   Anirudh Singh      1
# 334         A Nehra      1
# 335        TA Boult      1
#
# [336 rows x 2 columns]

# %% [markdown]
# ## Insights and Observations:
# - Matches Per Year: The number of matches played each year shows an increasing trend until a certain point, indicating the growth and popularity of the IPL. After reaching a peak, the number remains relatively stable.
#
# - Venue Hosting Matches: Eden Gardens appears to have hosted the most number of IPL matches, indicating its significance as a venue for the tournament.
#
# - Toss Decisions: Teams seem to prefer fielding first slightly more than batting first after winning the toss, as observed from the toss decisions made across matches.
#
# - Matches Won based on Toss Decision: There seems to be a fairly balanced outcome between teams winning matches when choosing to bat first and field first after winning the toss.
#
# - Batsmen with Most Run-Outs: The top batsmen involved in run-outs across seasons might indicate their aggressive running between the wickets or instances of misunderstanding while running.
#
# - Hard-Hitting Ability: Players with the most number of boundaries (4s and 6s) tend to showcase a higher hard-hitting ability, crucial for scoring more runs in limited-overs cricket.
#
# - Dismissals via Caught and Bowled: Some players are consistently getting dismissed via 'caught and bowled,' possibly suggesting either their aggressive batting style or the bowlers' ability to induce such dismissals.
